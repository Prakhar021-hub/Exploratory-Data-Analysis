# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("train.csv")

# %% [markdown]
# ## EDA

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Age
# 1. it is almost normally distributes
# 2. it has outliers
# 3. contains many null values  (around 20 percent)
#
# **conc**

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Age'].isnull().sum()/len(df['Age'])*100
# Out:
# 19.865319865319865

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Age'] >70 ]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %% [markdown]
# ## Fare
#
# **conc**
#
# 1. there is major problem, the fare is the grouped fare of the passengers travelling in the group,  (and not the individual fare ) needs attention during feature engineering
# 2. the distribution is skewed
# 3. outliers present

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %% [markdown]
# ### Suvived
# 1. 61 percent of the passengers couldn;t survived
#
# **conc**

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts()[0]/df['Survived'].value_counts().sum()*100
# Out:
# 61.61616161616161

# %% [markdown]
# ### Pclass
# 1. majority of the people were travelling from class 3 followed by class 1 (which is strange) and then class 2
# 2. doesnot contain any missing values
#
#
# **conc**

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# ### Sex
#
# **conc**
# 1. 64 percent of the passengers were males and only 36 percent were females

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts()[0]/df['Sex'].value_counts().sum()*100
# Out:
# C:\Users\prakh\AppData\Local\Temp\ipykernel_13476\826478735.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['Sex'].value_counts()[0]/df['Sex'].value_counts().sum()*100
# 64.75869809203144

# %% [markdown]
# ## Embarked
#
# **conc**
# 1. 644 passengers were travelling from Southhampton, 168 from Cherbourg , and 77 from Quinsland

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
##Bivariate analysis

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### survived and Pclass
#
# **conclusion**
# 1. from pclass 1 37percent of the passangers were not able to survive, from class 2 52percent of the passangers and from class 3 75percent of the passangers were not able to survive. this shows that more priority is given to the class 1 then 2 then 3

# %%
pd.crosstab(df['Survived'], df['Pclass'], normalize='columns')
# Out:
# Pclass          1         2         3
# Survived
# 0         0.37037  0.527174  0.757637
# 1         0.62963  0.472826  0.242363

# %% [markdown]
# ### survived and sex
# **conclusion**
# 1. Survival rate of the females are far more than male

# %%
pd.crosstab(df['Survived'], df['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %% [markdown]
# ### Survived and Embarked
# **conc**
# 1. one strange thing is the survival percentage of the passangers travelling from cherbourg is quite much comparission to others
# 2. from cherbourg more passengers were travelling from Pclass 1 and also the percentage of females travelling from cherbourg were decent  and thus they have more survival rate

# %%
pd.crosstab(df['Survived'], df['Embarked'] , normalize = 'columns')* 100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
pd.crosstab(df['Embarked'], df['Pclass'])
# Out:
# Pclass      1    2    3
# Embarked
# C          85   17   66
# Q           2    3   72
# S         127  164  353

# %%
pd.crosstab(df['Sex'], df['Embarked'] ,normalize='columns')
# Out:
# Embarked         C         Q         S
# Sex
# female    0.434524  0.467532  0.315217
# male      0.565476  0.532468  0.684783

# %% [markdown]
# ## Age and Survival
#
# **conc**
# 1. the plot shows that the more priority was given to the passengers of the age group between 0 to 15 , and also the survival of passengers aged between 38 to 42 is more

# %%
df[df['Survived']==1]['Age'].plot(kind='kde', label='Survided')
df[df['Survived']==0]['Age'].plot(kind='kde', label='not survived')

plt.legend()
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[df['Ticket'] == 'CA 2144']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60         0       3       Goodwin, Master. William Frederick
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 386          387         0       3          Goodwin, Master. Sidney Leonard
# 480          481         0       3           Goodwin, Master. Harold Victor
# 678          679         0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684         0       3              Goodwin, Mr. Charles Edward
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# 480    male   9.0      5      2  CA 2144  46.9   NaN        S
# 678  female  43.0      1      6  CA 2144  46.9   NaN        S
# 683    male  14.0      5      2  CA 2144  46.9   NaN        S

# %%
# we can notice that the total no of the people should be travelling with ticket CA 2144 should be 8 (5 SibSp + 2 Parch + 1 oneself) but here we have 
# only 7 people , implies the data is missing....

# %%
df1=pd.read_csv('test.csv')
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df1[df1['Ticket']== 'CA 2144']
# Out:
#      PassengerId  Pclass                            Name     Sex   Age  SibSp  \
# 139         1031       3  Goodwin, Mr. Charles Frederick    male  40.0      1
# 140         1032       3     Goodwin, Miss. Jessie Allis  female  10.0      5
#
#      Parch   Ticket  Fare Cabin Embarked
# 139      6  CA 2144  46.9   NaN        S
# 140      2  CA 2144  46.9   NaN        S

# %%
## so the data wasn't missing it was presrnt on the test table

# %%
df=pd.concat([df, df1])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Ticket'] == 'CA 2144']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60       0.0       3       Goodwin, Master. William Frederick
# 71            72       0.0       3               Goodwin, Miss. Lillian Amy
# 386          387       0.0       3          Goodwin, Master. Sidney Leonard
# 480          481       0.0       3           Goodwin, Master. Harold Victor
# 678          679       0.0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684       0.0       3              Goodwin, Mr. Charles Edward
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# ...

# %%
# now our SibSp and Parch column is consistant and we can create an individual fare column for better understanding

# %%
df['individual_fare']=df['Fare']/(df['SibSp'] + df['Parch'] + 1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].describe()
# Out:
# count    1046.000000
# mean       29.881138
# std        14.413493
# min         0.170000
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
df['Age'].fillna(df['Age'].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId           0
# Survived            418
# Pclass                0
# Name                  0
# Sex                   0
# Age                   0
# SibSp                 0
# Parch                 0
# Ticket                0
# Fare                  1
# Cabin              1014
# Embarked              2
# individual_fare       1
# dtype: int64

# %%
df["family_size"] = df['SibSp'] + df["Parch"] + 1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df['family_size'].value_counts()
# Out:
# family_size
# 1     790
# 2     235
# 3     159
# 4      43
# 6      25
# 5      22
# 7      16
# 11     11
# 8       8
# Name: count, dtype: int64

# %%
def update_family(num):
    if num==1:
        return "alone"
    elif num >1 and num<5:
        return "small family"
    else:
        return "large family"

# %%
df["family_type"]=df["family_size"].apply(update_family)

# %%
pd.crosstab(df["Survived"], df['family_type'], normalize="columns")*100
# Out:
# family_type      alone  large family  small family
# Survived
# 0.0          69.646182     83.870968     42.123288
# 1.0          30.353818     16.129032     57.876712

# %%
## insights/ conclusions
# chances of a person's survival travelling in a small family is quite good

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# Notes
# 1. In the above data frame 'PassengerId' and 'cabin'(cabin could have been useful but it contains alot of missing values) is not so useful column which can be removed before model training
# 2. Data encoding on the columns like 'Sex' , 'Embarked' , and 'family_type' can be done before model training
# 3. We can also perform feature scalling on the data frame before model traning.
